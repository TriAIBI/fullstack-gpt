# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

haiku_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "",
        ),
        ("human", "I want to write  the poem about {programlang} prgramming language."),
    ]
)

haiku_chain = haiku_prompt | chat

# %%
haiku_explain_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a haiku expert who can explain about the haiku associated with the specific programming language.",
        ),
        ("human", "{haiku}"),
    ]
)


haiku_explain_chain = haiku_explain_prompt | chat


final_chain = {"haiku": haiku_chain} | haiku_explain_chain 

final_chain.invoke({"programlang": "SQL"})
# Out:
# In the world of data, where queries reign,
# There lies a language, both simple and plain.
# SQL, the tool of the database king,
# Where tables and rows dance and sing.
#
# Select, insert, update, delete,
# Commands that make the data complete.
# Joins and unions, where tables meet,
# To retrieve information, fast and neat.
#
# Structured Query Language, precise and clear,
# Manipulating data without fear.
# Indexes and keys, to organize the store,
# Efficiently fetching what we implore.
#
# From MySQL to Oracle, SQL stands tall,
# A universal language, used by all.
# In the realm of databases, it holds the key,
# Unlocking the secrets for all to see.
#
# So let us praise this language of might,
# For in the world of data, it shines bright.
# SQL, the backbone of information's domain,
# A powerful tool, never in vain.This beautiful poem captures the essence of SQL (Structured Query Language) perfectly. Haiku, a form of traditional Japanese poetry, can also be used to describe the characteristics of SQL:
#
# In tables they dwell,
# Queries whisper, data flows,
# SQL, the king's tongue.
#
# This haiku reflects the simplicity and power of SQL in managing and manipulating data in databases. The structured nature of SQL, with its commands like SELECT, INSERT, UPDATE, and DELETE, allows for precise control over data. Just like a haestro composing a haiku, a programmer uses SQL to craft and retrieve information efficiently.
# AIMessageChunk(content="This beautiful poem captures the essence of SQL (Structured Query Language) perfectly. Haiku, a form of traditional Japanese poetry, can also be used to describe the characteristics of SQL:\n\nIn tables they dwell,\nQueries whisper, data flows,\nSQL, the king's tongue.\n\nThis haiku reflects the simplicity and power of SQL in managing and manipulating data in databases. The structured nature of SQL, with its commands like SELECT, INSERT, UPDATE, and DELETE, allows for precise control over data. Just like a haestro composing a haiku, a programmer uses SQL to craft and retrieve information efficiently.")
