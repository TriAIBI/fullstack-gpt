# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

haiku_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "",
        ),
        ("human", "I want to write  the poem about {programlang} prgramming language."),
    ]
)

haiku_chain = haiku_prompt | chat

# %%
haiku_explain_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a haiku expert who can explain about the haiku associated with the specific programming language.",
        ),
        ("human", "{haiku}"),
    ]
)


haiku_explain_chain = haiku_explain_prompt | chat


final_chain = {"haiku": haiku_chain} | haiku_explain_chain 

final_chain.invoke({"programlang": "COBOL"})
# Out:
# In the world of code, where languages reign,
# There's one that stands out, not in vain.
# COBOL, with its structured grace,
# A language of the past, yet still in place.
#
# Born in the 1950s, it paved the way,
# For business applications to have their say.
# With its verbosity and columns neat,
# COBOL programs are a true feat.
#
# Data division, procedure division,
# Working-storage section with precision.
# Performing loops and branching paths,
# COBOL's logic never falters or strays.
#
# In the world of tech, where trends come and go,
# COBOL remains steadfast, a steady flow.
# For banking systems and government needs,
# COBOL's reliability always succeeds.
#
# So here's to COBOL, a language so grand,
# Standing the test of time, forever in demand.
# In a world of innovation and change,
# COBOL's legacy will always remain.COBOL haiku,
# Legacy of structured grace,
# Stands the test of time.
# AIMessageChunk(content='COBOL haiku,\nLegacy of structured grace,\nStands the test of time.')
