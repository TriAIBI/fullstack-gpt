# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

haiku_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "",
        ),
        ("human", "I want to write  the poem about {programlang} prgramming language."),
    ]
)

haiku_chain = haiku_prompt | chat

# %%
haiku_explain_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a haiku expert who can explain about the haiku associated with the specific programming language.",
        ),
        ("human", "{haiku}"),
    ]
)


haiku_explain_chain = haiku_explain_prompt | chat


final_chain = {"haiku": haiku_chain} | haiku_explain_chain 

final_chain.invoke({"programlang": "SQL"})
# Out:
# In the world of code, where languages reign,
# There's one that stands out, not in vain.
# COBOL, the stalwart, the tried and true,
# A language of power, with much to do.
#
# Born in the sixties, it's stood the test of time,
# Used in business, in every clime.
# Its syntax may be verbose and old,
# But its capabilities are manifold.
#
# With data divisions and paragraphs galore,
# COBOL programs handle tasks and more.
# From banking to insurance, it's the backbone,
# Ensuring systems run smoothly, not prone to groan.
#
# Though some may scoff at its vintage style,
# COBOL's reliability makes them smile.
# For when it comes to handling data with care,
# COBOL programmers are always there.
#
# So here's to COBOL, the unsung hero,
# Keeping our systems running, never a zero.
# In a world of ever-changing tech and trends,
# COBOL endures, a language that transcends.COBOL haiku,
# Stalwart of the coding world,
# Enduring and true.
# AIMessageChunk(content='COBOL haiku,\nStalwart of the coding world,\nEnduring and true.')
