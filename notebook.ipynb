# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

haiku_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "",
        ),
        ("human", "I want to write  the poem about {programlang} prgramming language."),
    ]
)

haiku_chain = haiku_prompt | chat

# %%
haiku_explain_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a haiku expert who can explain about the haiku associated with the specific programming language.",
        ),
        ("human", "{haiku}"),
    ]
)


haiku_explain_chain = haiku_explain_prompt | chat


final_chain = {"haiku": haiku_chain} | haiku_explain_chain 

final_chain.invoke({"programlang": "SQL"})
# Out:
# In the world of data, where queries reign,
# There lies a language, both simple and plain.
# SQL, the tool of the database king,
# Where tables and rows dance and sing.
#
# Select, insert, update, delete,
# Commands that make the data complete.
# Joins and unions, where tables meet,
# In SQL, the possibilities are sweet.
#
# From MySQL to PostgreSQL,
# SQL is the language that we all boast.
# Efficient and powerful, it never fails,
# In the world of databases, it prevails.
#
# So let us write queries, elegant and clear,
# In SQL, the language we hold dear.
# For in the realm of data and code,
# SQL is the language that helps us decode.In the realm of code,
# SQL reigns supreme and bold,
# Queries unfold.
# AIMessageChunk(content='In the realm of code,\nSQL reigns supreme and bold,\nQueries unfold.')
